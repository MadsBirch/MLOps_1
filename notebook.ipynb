# %% [markdown]
# ### TODO:
#
# - Investigate images for what corruption has been added.
# - Create data loader.
# - Create model.
# - Implement train and validation.
#     - Plot training loss.
#     - Print validation acc.

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torchvision

import torch.optim as optim

from data import get_dataloaders

from model import CNN
from tqdm import tqdm

trainloader, _ = get_dataloaders()

# Set device
device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
trainloader, testloader = get_dataloaders()
len(testloader)
# Out:
# 79

# %%
dict = np.load('./corruptmnist/train_4.npz')
list(dict.keys())
# Out:
# ['images', 'labels', 'allow_pickle']

# %%
width=5
height=5
rows = 20
cols = 10
axes=[]
fig=plt.figure(figsize = (12,22))

for i in range(60):
    axes.append(fig.add_subplot(rows, cols, i+1))
    image = images[i]
    plt.imshow(image, cmap='gray')
    axes[-1].axis('off')  

fig.tight_layout()    
plt.show()
